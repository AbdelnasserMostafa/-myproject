# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdelnasserMostafa/-myproject/blob/master/Kerars_Generative_Models_Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lstm_text_generation.py Generates text from Nietzsche's writings

# %%
'''Example script to generate text from Nietzsche's writings.

At least 20 epochs are required before the generated text
starts sounding coherent.

It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.

If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# corpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
# Epoch 1/60
# 200285/200285 [==============================] - 318s 2ms/step - loss: 2.0036
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "o me."
#
# 282.--"but what has happened to "
# o me."
#
# 282.--"but what has happened to the word of the still of the self-condicious it is the world and the respection of the still the the morality, as the reart of the such the rears of the soul of the reart of the his of self-conditions of the such a something the still the world and standing that the responsed the really and the really of the most the morality of the still the reart that the reart that the reartic and intermation o
# ----- diversity: 0.5
# ----- Generating with seed: "o me."
#
# 282.--"but what has happened to "
# o me."
#
# 282.--"but what has happened to an has in the alsest such as morality, is of the moraling
# the that the contrature that which even the the stignor of the such a speciess of strang, of the is the right which it is whill which the rears, and the same of the amte all the reash with which the scient of selition in the hild shor in the works--the rations such a has one such a gentical life, which is the prosoul and in the respossed in
# ----- diversity: 1.0
# ----- Generating with seed: "o me."
#
# 282.--"but what has happened to "
# o me."
#
# 282.--"but what has happened to of d self-forselffual we its sumpot that the upphicestation
# cosond which ivition. as the know
# is the men of the shigaculy, inspeting the reencato
# wood muscrionationation of the scient, sciencess, destinst
# can soultly, framustes of only soitities, it, insulination and the read is in the would powserpict, cillagionatiod of abeke for pevewords, ligity of whenese called even the
# concemst, arus? one of
# ----- diversity: 1.2
# ----- Generating with seed: "o me."
#
# 282.--"but what has happened to "
# o me."
#
# 282.--"but what has happened to =all
# bast of one we or disfobnount, sporel-stispicery,, atful
# agricilly the him not of
# lust nguragis-that, is hourns--ofttecospfives untoduvt his could sheichy itle hodiginaly
# were
# the las act which, plyom.
# g,eraliment not earay by liferhing, ie becone (prodmy  doest humnoters--onace dreatabycum, is lawlery h anaiviry of grigducable--we whatle the hight it
# uevs is scionnitiativities behowing to it
# Epoch 2/60
# 200285/200285 [==============================] - 309s 2ms/step - loss: 1.6477
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "er praise, no longer blame, for it is ir"
# er praise, no longer blame, for it is irstrong in the such a strong and the surpicion and its little the problem to the philosophers and intencial interpretation of the prosourt of the problem to such as the soul one with the strong in the prosourt and intencial the strong in the problem to the possible to such a such a stands and in the problem to the philosophers and consting in the fact the soul of the stranger the stand with the suc
# ----- diversity: 0.5
# ----- Generating with seed: "er praise, no longer blame, for it is ir"
# er praise, no longer blame, for it is irnemating so science in the religions and religions and shat we which sense, the
# will, the so the will, the parting to be beather the serious and sense, the gorself with the view of the something to all the very reading that is a consting any consequence the incience with the strong it is plable is a strang in the conscience as the god it as reflect in the conscious of its abmains the artility the
# ----- diversity: 1.0
# ----- Generating with seed: "er praise, no longer blame, for it is ir"
# er praise, no longer blame, for it is irrewards, as sush his in the guold you like
# inianing inpenditional can through is great
# otelicamoncing as i reates and unifrem of rifear and
# serdition from presimamis irnelism thre god" is gitraal powered that such when the
# chiminal of our the consemporation, in back can still, fore intolest leve so as to one they all this sidled, year in satele, any
# made feanly burcons, cannem through thees be peo
# ----- diversity: 1.2
# ----- Generating with seed: "er praise, no longer blame, for it is ir"
# er praise, no longer blame, for it is irees a fawhien, which belief in
# its-lesele that the brellnted jois dempathy, nurdst, recroable happinatround, now fyxt; do naters to theigh can, one we propooctical semulity in revere.
#
#       lecking as would bitt be fact shat as there spipie and
# threame. after. illvicionary, but these causes the geimamen,
# previdestion, those. himse various naclet progress, whrac his consead first vore
# almost natur
# Epoch 3/60
# 200285/200285 [==============================] - 158s 791us/step - loss: 1.5564
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "m and sublimity of moral
# questionablenes"
# m and sublimity of moral
# questionableness of the sensious and the sensious and the constitution of the presenting and the self and the sensious the latter the sensious and the such a struggle the sensious and the more of the sensious and the such a struggle of the sensious the the seem the sense of the sensious and and and the sensious and the sensious and the prosent in the feelings and the self man which and the servantion of the sens
# ----- diversity: 0.5
# ----- Generating with seed: "m and sublimity of moral
# questionablenes"
# m and sublimity of moral
# questionableness of the
# eduction that an ending, the art, the greatest, in the morality in its siffer actions and the religion will see when the morality the end of the will not that it experience with in the self gazit of them them all inductions of the self souls to different in the constitution with religion, and with it is the world" presense. there is the sensious in the sensious its last, and condience tha
# ----- diversity: 1.0
# ----- Generating with seed: "m and sublimity of moral
# questionablenes"
# m and sublimity of moral
# questionableness are
# the prefect firdelys, they and how relicater--here will on will ane just there are self conflictive dan. our every inteacude, to prestires, stas subtler only lives and vilous sce of else called sufferive utility, indeed hitherto the oddind" part, for his surperious godnis
# for what very dangerously, religion," to where something, morals to their germos of the strey, who still furinly, undermy
# ----- diversity: 1.2
# ----- Generating with seed: "m and sublimity of moral
# questionablenes"
# m and sublimity of moral
# questionableness, of actitate man must althing himselt: (by thus
# which,ed that in wisu's will
# has my becteduence, those the god it in those theirs, grows but the clesusing for thoufids me vogus lingle lifements for unalses of condica sleve perrettura for o
# briest,
# on its sul". ,
# trrofre?"
#
# ethrnations.
#
# 2ter and contust--ih? (theyr.
# it is one
# reentuation to our becess?"i, as in every. for the exasts envolicietio
# Epoch 4/60
# 200285/200285 [==============================] - 159s 794us/step - loss: 1.5117
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ends may be ignorant; his mortal danger "
# ends may be ignorant; his mortal danger the consequence of the subjection and the morals of the more subjection and any and in the same and the condition of the subjection of the subjection of the finally and and and the more the same of the subjection of an expression of the sensible and interpretation of the subjection of the belief and the world of the and an interpretation of the subjection of the subjection and such a stard and the
# ----- diversity: 0.5
# ----- Generating with seed: "ends may be ignorant; his mortal danger "
# ends may be ignorant; his mortal danger of century of at the instance of
# the will and and a mortusac of mankind to a german which has been shate the moral pain: the definited and the probably to other constant at leasing the being an at all suppose and any others, and the
# accustory which the "nowadays, at metaphysical and in the world and who has not be the belief and stand will and make the
# mander and into the because itself it is a re
# ----- diversity: 1.0
# ----- Generating with seed: "ends may be ignorant; his mortal danger "
# ends may be ignorant; his mortal danger than pows, their same sensiby of that, wholl under an according and plate i
# ontoodaris exishcal.--such a stsuils to at him; is of matters of mumition such now mennay unavoil, he ospunes edvance
# sensarty and of point, sames"";
# still "the errorary staital philomouseled
# guisting human, and
# help sudrer, nowaxhing. when it is natural, and god! that the saderey alily crurstomanianing,
# how heaken, has to
# ----- diversity: 1.2
# ----- Generating with seed: "ends may be ignorant; his mortal danger "
# ends may be ignorant; his mortal danger thees sicking in one"wa crett be blind of seom--withexh the quedion consequence. bo withionnatic bvont." aso," heoddelanly of extends has its keactal, beinay hithertoh, formand foreness"--semm for the herour intole the turnerfleust of judgments in order to these lowt--bloungful frabe vucity
# an error-hequice as
# thas mayeph and 's
# plays withe in a lis as to revently unfiim, memperrations, "are arist
# Epoch 5/60
# 200285/200285 [==============================] - 159s 796us/step - loss: 1.4808
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " limited only by the extent to which the"
#  limited only by the extent to which the sense of the sense of the sense of the consequently the sense of the such a serve and self-pancies of the sense of the suffering the sentiments of the suffering the sense of the sense of the sentiment the sense of the superficient the substance the sense of the sense of the such a strength of the sense of the sense of the sense of the sense of the senther of the sense of the extent the sense of t
# ----- diversity: 0.5
# ----- Generating with seed: " limited only by the extent to which the"
#  limited only by the extent to which the lack to his such a pasining and respirit of the demond the force and exception the subsivicious it is a will and this depense of the senseating, and another itself, and super the cause of the ascendentally, and asseries and truthful, with the pain to be for the delight to the delight of the sensible of this can the world and such a passions of the sole the constant sense, as the world and strengt
# ----- diversity: 1.0
# ----- Generating with seed: " limited only by the extent to which the"
#  limited only by the extent to which the such a case now his cases of manuaties.
#
# 31. the or
# aftermy,
# pre? newrong the surchenses merets hadity from by distord, and pride, the opical above task: are still a courality at frelition, in nothing everything is morality.
#
# 229.. i ste do genuiness, even the commush
# which he will be as, men
# authoriners, a recrieing see
# the in makelef-sibe standards, but cantemuines, or when a proof that
# is natu
# ----- diversity: 1.2
# ----- Generating with seed: " limited only by the extent to which the"
#  limited only by the extent to which the winctoymanized, for sheub!ed to roout to suncher, all the dispooy-ding, surpondistincy,, diin
# furnest this
# dises
# and
# highom expense the
# soild,"--how most "as  most, their pain, as to not even the ! just the mankir liet admimns ares in corrous. he was
# the feeled accuation for the conduct it we'l really on that the most rideness
# of the munatibanblated. that tyre long powed veri him and his pain int
# Epoch 6/60
# 200285/200285 [==============================] - 159s 792us/step - loss: 1.4631
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "h separates two men most profoundly is a"
# h separates two men most profoundly is all the problem of the consider of the world and precisely and consider of the sension of the present of the problem the problem of the problem of the world and present the world of the soul of the power to self-present of the sension of the desire and the problem of the one must be desire and problem of the world and god. the most understand the world and present the present of the problem of the
# ----- diversity: 0.5
# ----- Generating with seed: "h separates two men most profoundly is a"
# h separates two men most profoundly is all the consequence of it, but the wand and pained to it is a thinker and the contempthy of the reperson and prevartion of the greatest by the great power the existence of the has a philosopher to him in the considest of the
# master of the martion. and granses, and which might so were the theirer present of the greaters the origin in the stride that is the apparent in another--the world as the contr
# ----- diversity: 1.0
# ----- Generating with seed: "h separates two men most profoundly is a"
# h separates two men most profoundly is attaine its against and prohimant,-alithess--are knowledge  "go everywher, of the bystrophaled new
# work and out of the bove contrid,"--so rities, as things loty'gly and paithe, which too ole certained
# nowadayse, they, not fal., is a seeabutided day is nature is contimpri,ier."
#
# aciled is perhaps or consepore. one utild adove notion is world and pracestion.
#
# 22. the
# could
# have perponance ear precise
# ----- diversity: 1.2
# ----- Generating with seed: "h separates two men most profoundly is a"
# h separates two men most profoundly is as ate not, all,   not his dogairly counded with flacty in man he experitarity as posely. them to the
# dainted.
# in rink hequike," one ascrections; fastful of the the erromow. moativeny: and glan, wich croud germen ot he error to onesel the betanhe it; uncertainly retaining enough i who. whhigh eacesul ofs actrase of the sensised
# inligher antistible on this and day arfire our-himath tornus; tou, the
# Epoch 7/60
# 200285/200285 [==============================] - 158s 791us/step - loss: 1.4498
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "row up in connection and relationship wi"
# row up in connection and relationship will be the sense of the spirituality of the senses that the strength the senses that the sense of the contrary to the strength the subless of the sense of the partical of the conscience as a subless of the dogain the sense of the strange as the senses to the senses to the sought the dogain in the intention of the sense of the belongs to something the subject of the powerful the sense of the sense o
# ----- diversity: 0.5
# ----- Generating with seed: "row up in connection and relationship wi"
# row up in connection and relationship will be belongs to the very others when it is the among strength man who one mankind than the ready and grows it is the does be the contribations and the great party of the sensation, as the constitute with the same morality, in the remained the reality and ourselves that the conscious that we have only to punishing limition--and the truth is the for the strength and ready personal for the condition
# ----- diversity: 1.0
# ----- Generating with seed: "row up in connection and relationship wi"
# row up in connection and relationship with it.
#
#
# 10
#
# =is, and hors
# false the gosce, ne may others laws, fash at adorpks those
# who
# especiss passion.
# in their
# voctible? "as, insists home andour primittitful love when such give to
# conjusing astituated to bear, theres punishment, its must dinty does not was see, a
# morals,
# so philosophy worss, falso-doistos it is the to conscribes doan as they personsingp pothan
# prilicis and fruen and though
# ----- diversity: 1.2
# ----- Generating with seed: "row up in connection and relationship wi"
# row up in connection and relationship witese obligatons to human it, we such figring,"
# (a hrougg!, thang tauneply bibly believed
# by a irour
# oths as tuanfces!" omosey-aifmo xated than protic withid than otf
# comm in fact the things, he pulf: he attor uplist constinuples, rignagl and woman qualine, no means con"--demotilism out, apo-bound assi-d .sourabit,ly to aometaxmsa
# suveus."
# . how for its sosms fall rewardly
# people ciodd sooks will o
# Epoch 8/60
# 200285/200285 [==============================] - 159s 794us/step - loss: 1.4402
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ith regard to its worth: a great achieve"
# ith regard to its worth: a great achiever to the present that the strange to the present that it is the strange to the struggle in the strength of the substance of the present the strange and as a present the most struenzant and a struggle and a present of the strength of the strong and in the struenzant and in the struggle and also the struggle to say to say is the present of the conscience and in the constant that it is so that is the
# ----- diversity: 0.5
# ----- Generating with seed: "ith regard to its worth: a great achieve"
# ith regard to its worth: a great achiever the hand of the rare presund the man world as a most still love, through the man be the sears and much to the possible the spiritual to the present the consciousness of this does the repose the astifugg to it may the most have the here the standing a consciously in the worlder of the properful is a most struggle in the power. the endeave the properlity of the down and another of the partiful in
# ----- diversity: 1.0
# ----- Generating with seed: "ith regard to its worth: a great achieve"
# ith regard to its worth: a great achiever certain to a whomigh from with this
# necessarily says; are yout, learn neing when it knows
# hoid, with which this to so instearly is mood then look them, which forming that in appear that they we kep to not like ip.ablied and the old
# pholame is to wear now have to learn presenis.--al si out frectual soulism of visible specent though believe here
# prator lowable a . sange and even indiviation as act
# ----- diversity: 1.2
# ----- Generating with seed: "ith regard to its worth: a great achieve"
# ith regard to its worth: a great achiever. they have judiclary
# aticiwarious sighted to truth; we is itself.
# there those moralilice an early
# chood really even of this saint for mis. linge thenieons to even it betwer; and originate framman to
# becom--cleally child, as a sume origins of agried becence--this more to us; for it and what no
# longer to oppsious worke there, at which will says, as your in himself to fils word us recllited tithin
#
# Epoch 9/60
# 200285/200285 [==============================] - 160s 801us/step - loss: 1.4308
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ogance, for the transcendental
# height of"
# ogance, for the transcendental
# height of the procession to the processive the partical the sense of the procession the processive the procession the properation of the profound th
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: divide by zero encountered in log
# e procession of the strength and the procession the most believed the most and the procession of the the proper and the strangtions of the processive the standard the procession of the procession the contempt of the procession the transficition of the strangtio
# ----- diversity: 0.5
# ----- Generating with seed: "ogance, for the transcendental
# height of"
# ogance, for the transcendental
# height of the higher spirit the pride and
# taken and and superfational this philosopher and the completable the proper the prolidion to it is the has need of the truth and to life he is a read the most seems and life and the sense in the contempt to still the partical the contempt for his construment and the conscientity to the history and the particulary cases of the heart and this is not not be profound i
# ----- diversity: 1.0
# ----- Generating with seed: "ogance, for the transcendental
# height of"
# ogance, for the transcendental
# height of virtues of the advegain which only it "inclustion ammed has gadies! what
# nature in their
# happiness," , of it, it is not lap, is nature of doubtful and diffrees calline tyre profist of instrument into the
# last in stappinen
# has by whom
# ogight secret, of sleverticly syaring "meted, for
# christianity if it said, all this taknece for his
# setires sases of exastration and a philople adlys of seived their
# ----- diversity: 1.2
# ----- Generating with seed: "ogance, for the transcendental
# height of"
# ogance, for the transcendental
# height of the deral, he
# hasiness
# quinties in the generates and ra, in bonh free andm and looks to plluditr his simanhes
# this who they to than the as
#      omy? where, at emithatog! as in
# alonaw modes of asserts
# detactration from proporisr. therein accustomed honlightyd compensibled him"erulnesss? it is
# justify this usosingehy that have not deciining life valuatifiesd. man spiritsih
# oranguationed with the
# Epoch 10/60
# 200285/200285 [==============================] - 162s 809us/step - loss: 1.4212
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "uld not do
# so, however, if he knew that "
# uld not do
# so, however, if he knew that the present, and a substance of the sense--it is the own or the senses of the soul of the assertion of the present in the sense--i have a fact the sense, and the senses of the end, the present, and the man is the ascence of the present the sense" the truth and in the sense" and only a substance of the present of the sense of the present of the sense. in the present and more of the conscious of the
# ----- diversity: 0.5
# ----- Generating with seed: "uld not do
# so, however, if he knew that "
# uld not do
# so, however, if he knew that is not be nowadays in
# the precisely in the conscience and belief is the exception and for the will
# to the really the really the historic with the most obey himself in the priscition, the all religion of the present in the sarding the present
# of moral and and and certain them also have the can that the conscious and with a depresed and experiences, perhaps, the kind of science and the most recustom
# ----- diversity: 1.0
# ----- Generating with seed: "uld not do
# so, however, if he knew that "
# uld not do
# so, however, if he knew that the marcessary been truecesss--tumacts cryag of goodual diclartkness. you from as the reeks of his europeaniance of the impulsion there is naturally blindiction the most ones to their reflection and certain explanations
# of exception with the fartical fortunusic the trace problem,s who ! justis. mo usw
# the intelligene, falunger. that
# we know and womine feeling and barress and great
# plato, and in th
# ----- diversity: 1.2
# ----- Generating with seed: "uld not do
# so, however, if he knew that "
# uld not do
# so, however, if he knew that is as newly andi"ed which is it dependingly,
# it toest be tringceing itself in ali only rear-is hence ibes--it hus whose
# in everything, aresenfuluse is
# his worthd all micide reje; psychology: only
# fundamental at awern we cannedentdors,
# cryest portlee, in the editable their utilitguaging
# crotiftincturesd
# appear-tachesly,
# equan;trous etern, therein--allowed--that kfinchlds to
# the
# bold
# refroctities, t
# Epoch 11/60
# 200285/200285 [==============================] - 172s 860us/step - loss: 1.4140
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "on whether this which is "given" does no"
# on whether this which is "given" does not the sense of the subject of the sense, the soul and sense of the sense of the senses and the proper the soul of the senting the order to the sense of the proper and the proper the first the self-demons and the proper the truths and sense of the proper the standars the properation the properation and the proper the sense of the sense of the probably the saint and the subject of the senting the se
# ----- diversity: 0.5
# ----- Generating with seed: "on whether this which is "given" does no"
# on whether this which is "given" does not proved and properable and life--evil and responsibility of the contempt of the hoid of the end, in the power of the significe to all the continuation fear home end the freedom of love of the contrary the possible the senses and of the more of the high and propount to the unconscined and man of the enduring the propount reading and more standarisness have
# the senses and in the happiness of one an
# ----- diversity: 1.0
# ----- Generating with seed: "on whether this which is "given" does no"
# on whether this which is "given" does not
# will" need in
# compacrity and understand. how power, thense opinion of our worsdy repose of moral start a sympathis especially
# with so into
# the strength of the whole notion life is
# higher that it possible oving and produces. there are lobelly fundamdnissons.
#
#
# 121. help, re, septionally make dream" espectal in lefter in moral penturion; so far-forstrichter, is that
# much
# sentiness bo raling can re
# ----- diversity: 1.2
# ----- Generating with seed: "on whether this which is "given" does no"
# on whether this which is "given" does not the fictious
# time much, the fuelogies? is shiller
# negluling art renual attinus, higher regardant only--for is to ma-nherquio--dhe rows that the laftelens (tenden, in in, thereingriality itself.
#
# 93
#
# jehabwh
# metrops:--it is boopice with suficitios
# itssuch
# kcroanies; and the advances he "or who under theaq") agn once of
# its temunance
# itself than he himself andly friends for a fundancys
# senwing,ly
# Epoch 12/60
# 200285/200285 [==============================] - 173s 863us/step - loss: 1.4087
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: " realms of the future--let us go with al"
#  realms of the future--let us go with all the contemplation of the philosopher and profound the philosopher and the will to the contrary and the provers the will and the philosopher and the will and the fact the will to be a philosopher and the philosopher and the morality and the morality of the philosopher and the will to the morality and the morality and the considerable and the contemplation of the morality and the will and the mora
# ----- diversity: 0.5
# ----- Generating with seed: " realms of the future--let us go with al"
#  realms of the future--let us go with all the
# common of at any profound themselves as the complete streeth of the belief of the philosophical the greatest points the class.
# and receiting themselves the wome consequence, in the moral expression of morals"--he praisian ages as become to the word and complete the world, it is the a problemac without which and the instinctions and though ourselves which is as have and the points of this bec
# ----- diversity: 1.0
# ----- Generating with seed: " realms of the future--let us go with al"
#  realms of the future--let us go with all the more variation. does,
# if him it then, fored ant--still old the wile.
# this; in
# the
# pleases to
# oys to phynou without secret of the behone, so delight to be unood to all sentially joy hard
# and ridative restrance honest, and the strange, a drip, on lumbatboully
# truth-spomanity preachtism of risule they
# desires now morals of
# intele
# possitions that
# and spetk. there are dappe at sidnicis; butily ho
# ----- diversity: 1.2
# ----- Generating with seed: " realms of the future--let us go with al"
#  realms of the future--let us go with also a physic bedrys
# fromeif. not,
# to doubt at the moral suphes not-mer first
# enouwh before and fragits arttsible dago-crosed of melftience shmel; hoves regardityd morality saliduts.
#
#
# 114
# seg divents ao lo
# for an rated mairawity!"
# sure habit.=--any relal
# doffers,ing end immease what thrim homews-le
# of the
# places of canno acknowoorth;
# lif a
# of wise--that
# nater at they with causesed! by the benour pa
# Epoch 13/60
# 200285/200285 [==============================] - 162s 811us/step - loss: 1.3993
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "effulgence which o'erspreads a sovereign"
# effulgence which o'erspreads a sovereign to the soul of the standard to the sentiments of the transficured and the conscience and in the possible and the possible to the standard to the standard to the conscience and the most such a subsernative and possess of the possible the standard to be a philosophy and the conscience and the the standard to be wish the conscience and a strange and something to the strength and the standard and the
# ----- diversity: 0.5
# ----- Generating with seed: "effulgence which o'erspreads a sovereign"
# effulgence which o'erspreads a sovereign of form to the world and has to the conduct of hersed only her went will not not be conception of the probably to the spons, and a state of their strange the sense, and it was the belongs and desire of the conscience of the end, in the standars they is he suble the conscience and as a free suppose and it is a forticists of the essential fact to in sees to be dreams and instrument of the soul in a
# ----- diversity: 1.0
# ----- Generating with seed: "effulgence which o'erspreads a sovereign"
# effulgence which o'erspreads a sovereigne you is that self-pan antimitable infivalr estitues to whose meritactive taste, and movements of the standarfol, himself--but hhoujsed is spees, an into to man; who
# say, stronges with it, and some fact-especr
# life and sub and himself time upon the togethey, in this neithering wy scholars
# as less a mind. which demands and beourdored to whereons
# olings-inythers to maint not intellects are still hav
# ----- diversity: 1.2
# ----- Generating with seed: "effulgence which o'erspreads a sovereign"
# effulgence which o'erspreads a sovereignic musters gon"d, indeed, how sus, any pament,
# ketviry,
# standance--an ere ordanted's and it in
# class! attemivosnuce, so chrilitart new da! whill bruth is found hupws, need of his
# genera
# even entiugraby custors ca   toad how, what. "we"--strongs. disad nothingseln distribine
# hitheris fortual ruise of detles, dtoe, illnce has the groid towards for houses, hs towards we intheid these morality naturea
# Epoch 14/60
# 200285/200285 [==============================] - 163s 813us/step - loss: 1.4145
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "sentiments, he who has such
# knowledge ab"
# sentiments, he who has such
# knowledge about the soul of the probar to the considence of the strength of the most delight of the soul of the conception and and and in the soul in the same as a strangestic and and who will and the sense, and the world and pressed the strangless and the most pressed in the contraring of the morality and the contrarixtice in the same probar the considence of the consideration of the considerations of the co
# ----- diversity: 0.5
# ----- Generating with seed: "sentiments, he who has such
# knowledge ab"
# sentiments, he who has such
# knowledge about the lawar, and to life and pressing the heart and with the morality and a merely not and has also the great interpes of which the considence and far of
# a subjection, in the strength, the subjection of constitute in which the progreated and
# man would be action and conscience and what the soul itself and understand in the doynse of the religious distarment that they have are as the consider of
# a
# ----- diversity: 1.0
# ----- Generating with seed: "sentiments, he who has such
# knowledge ab"
# sentiments, he who has such
# knowledge abong
# thats, and which one; as to the conaction of any, ile has been stupinins of his act, man will. sose! however that a diss"ument.
# it there
# are not antads
# the "more someinge
# duadity, a
# chanchistration in life any
# shole among" betrimifax christianily. however,
# as the crusition we so doentless every distrawness,
# with all in the ton
# creature
# of
# numberition in the (ow : none".
#
#
# 131
#
# =endsate. too th
# ----- diversity: 1.2
# ----- Generating with seed: "sentiments, he who has such
# knowledge ab"
# sentiments, he who has such
# knowledge about im
# lutuing form and whllveene dangerance powerful that
# oth here knowledgesable go-guilly acition:--ury are nal it connefic ow.--howevyar
# weak."
# unisg garging which, worssing! and a state of remotested spoins begor some sorifior
# is begints it and hes it in it man"er, nogication--another the heart it is thurnfule it are must end and hasked forms an eye am raching because as and cause as who des
# Epoch 15/60
# 200285/200285 [==============================] - 163s 813us/step - loss: 1.4536
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "ll have to be the
# incarnated will to pow"
# ll have to be the
# incarnated will to power of the cäsicults the respect in the troung and soul of theäbreceëbce of the consequents and acturesëbjectäble and and the stread the world, äbaditëbquecre of the subjort of probeactäves and the stread theäbour, anäzxäbces of the most self-actualätion and soéboritic of the proberst the state and stéjecy of the coäjuät and the self-conductä--the will to be morality of the protension and the stëje
# ----- diversity: 0.5
# ----- Generating with seed: "ll have to be the
# incarnated will to pow"
# ll have to be the
# incarnated will to power. and theäbx? the conception in the concealugation serve only tëjess--the beliest which is the self-and existencesäperly and and abound with the otherselveëjust and the
# freerated to the greatire, and the conceitically be owëbces," of the responses, their enoäjour ëjbwer to the incävers and formeration andæby the bruntless menal ture the most strëqueæveëbce in the same the the conceptions of tëje
# ----- diversity: 1.0
# ----- Generating with seed: "ll have to be the
# incarnated will to pow"
# ll have to be the
# incarnated will to power poortilyäble bew soovy himself its
# prisentitusmslæk, éjbw rest and of moredntly, their estimawaëk, the gite logtëwé! and knd would be midstilabtent and seemer:ëmbtics; whién: the pro" existedest us"--and his fulls, in tëwars free.äburdly expressomalted, back: morals and aroæty anëughen amoriouævous profounded cunneven, at the
# recovebistioäjbw geängurity, turh milä"? how
# thoughts äve(lest--power
# ----- diversity: 1.2
# ----- Generating with seed: "ll have to be the
# incarnated will to pow"
# ll have to be the
# incarnated will to power-splishy ëmy edtentur anspehy
# in hea, consequentilal mäking condiæwëtu cextalities, smacing now mere case semi-prothcos! what bearfle."
#
#
# 61
#
# =man".
#
# 1ë9. their
# enophäful." with foamphanes; give perhaps dangersocleset--as heso soisticiæx
# of stronger
# will with its bithed as obspeciess where way of
# comination! but bëvé!
# as endagitish, the veryes the ëquietaped touth from, will alway will self
# pirä
# Epoch 16/60
# 200285/200285 [==============================] - 163s 814us/step - loss: 1.5242
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "a waking
# sleep, an enduring repose in th"
# a waking
# sleep, an enduring repose in the presument of the standaring such a still comprehend to the standares the fact and one stand of the standare and the standare and among the standares the standares the presumption of the standares of the experiences the most state of the extent and the subject of the standares and strong and also the suffering of the standares the subject of the pressed to the extent the sense of the subject of t
# ----- diversity: 0.5
# ----- Generating with seed: "a waking
# sleep, an enduring repose in th"
# a waking
# sleep, an enduring repose in the instinct and power that all the sense
# of the enemidity of the experiences of the standpain of the pressitian as it was the intellect of human approcrine the sense, the most morality in the suffering of particalist itself about the presument in the last one's stand not and present, but of the most midst in the standary and personal strength in the other self-care of the subject, that the will be
# ----- diversity: 1.0
# ----- Generating with seed: "a waking
# sleep, an enduring repose in th"
# a waking
# sleep, an enduring repose in the institute.ly the even, finally: eventsing the danger, among the
# gards
# scilncess.
#
# 20. hels they are and his prefernce
# na, ip. it is allect he with very action of praece, all thought for
# his present every medane sacracently with lo-cently, most triumation, which eough and xigaring he may therefore the end,arushed grands" have the envicists him.ess on the
# rellds of that a rult of the law that them
# ----- diversity: 1.2
# ----- Generating with seed: "a waking
# sleep, an enduring repose in th"
# a waking
# sleep, an enduring repose in this
# way as ne
# natural comens by assern
# mfir" the person to idea falsabley this inspire and interpresatity, in so optimate, southts, whik we one!iholwn virtue--but bernored, he who ocdendity itself--that man gratter cheicknt
# ineverely, need of the forfullus (agwin peomse,"hive would deal art relighacy: ot the hearts, that
# which
# is.
# it ilouquted mightward. i honeablis. madle and "nowacedly and wishin
# Epoch 17/60
# 200285/200285 [==============================] - 164s 818us/step - loss: 1.4045
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "ness of all these manifestations of powe"
# ness of all these manifestations of power and in the produne and morals and a still and the soul of a standing and the soul of the morality of the sense, and a subsequence and sense of the sense of the soul of the soul of the extends of the soul of the soul of the sense of the old morals and self--that is a standing of the soul of the self--the the soul of the soul of the soul of the sense of the soul of the consequences and history of
# ----- diversity: 0.5
# ----- Generating with seed: "ness of all these manifestations of powe"
# ness of all these manifestations of power and secures of commons in his soul of the soul such a sertion of which has the neither instincts and hunally the finally the things which the moral
# german or of the contrastic who is him of the moral strength of the herding of the way to be the apposciped to the soul of the stated to shade at heavely believed to feelings and what europe of reposes of what the ording, and here it is a philosophy
# ----- diversity: 1.0
# ----- Generating with seed: "ness of all these manifestations of powe"
# ness of all these manifestations of power trakens something when this very contempacy-offutting, in efficiality wuracror, all o these find or as sensible estimatic power
# endeduce
# for one and why may every saflllyémb order
# wakes: ! perhapling to other character, good-ly and unbress he respitht and godity of philosophicanies; whatever, easily forward and charmine, perhupent power whethersely his, insire
# inatgle." bourss to things are the
# ----- diversity: 1.2
# ----- Generating with seed: "ness of all these manifestations of powe"
# ness of all these manifestations of powerness: panceward but who me in the jeided to
# tley it all the
# proscricax much aäwhlever into a freered satisdomessier ades of
# an unsagknot of leastse, powens tæjed itsetpe--forncity. to their herdable nakested take clie.
# in bodbered
# a the branceacy, omyssing as way æpyaring,
# the old
# deferenceable serves condition instraiseä. they his radom endended something of effects
# of his bele. it ma, are not b
# Epoch 18/60
# 200285/200285 [==============================] - 166s 827us/step - loss: 1.6380
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "hemselves. it was to their interest that"
# hemselves. it was to their interest that the standare and the striving the standare of théble anäzation of the stard the more protest and an any self to the senses, and and the standare, and the standare, and the shalmeneät, the pardinatioä. the indurem of the striving the striving and täman and the striving a striving and the striving and the standare, and a strangest and an an an an inæstimatiäble and in the porter and the standare an
# ----- diversity: 0.5
# ----- Generating with seed: "hemselves. it was to their interest that"
# hemselves. it was to their interest that a passess the experious and only when the unconception and man in destrustaminess of reall in all and an exception of the one has been close the patration, a continal desirace and in arcide? that the surpens that the consession in opponitened äby satished of the parter and thath of the pall by the thing which not of the pate morl perhaps the depersorary the notion of some suæstification of striva
# ----- diversity: 1.0
# ----- Generating with seed: "hemselves. it was to their interest that"
# hemselves. it was to their interest that," lougherer its instiugly anote himseloge
# of only laughoy the worngly
# the usspecondesing a satished who surd,al prost, like not in comen to yet is with could darity, idea acts--thereftominess as that the anieves
# way of more alwhoue nation, betting lifes. a standa=s, that another always with has a cherdibatwing the process, suppection glansæs have,
# a thoular (as ontet perhamich that he danceen, pa
# ----- diversity: 1.2
# ----- Generating with seed: "hemselves. it was to their interest that"
# hemselves. it was to their interest that it
# is feed and conciuation if not that vantat.atbally byevonve him. perhaps
# great, schop
# thominary vivisiof at
# aime us as rejoine, freys
# to neels personsts and not immoral justiat which conquitiestydery (frome up, we sa consession egrankëble fur": the neeve oping espehable word, feut mirst
# neceaporacriangä"-thes thëäborgnatphand the essebotial onces them hurd, by this, that one
# jusuust--is a mada
# Epoch 19/60
# 200285/200285 [==============================] - 403s 2ms/step - loss: 2.0603
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ed
# aspects. now in the case of philosoph"
# ed
# aspects. now in the case of philosophy and the power and sensifical the sensific the problem of the or of the power and the most interpreting and the sensific to the probabit and the sense and explain the probabit and interprety of the probabit and the world and the world of the conscience and interpreting and the world the one who is the probabit of the probabit and the probabit and interpreting and the most such a philosophy and co
# ----- diversity: 0.5
# ----- Generating with seed: "ed
# aspects. now in the case of philosoph"
# ed
# aspects. now in the case of philosopher has the instinctited play the world world which have he is a more instinct the imperficiption--have that even of the perceive to say to his mean moral
# for it is any actively believe vany as all the religious in the history for the profound are no longer on his distance
# and probably best and sides and the good significal in the fight by the sloves and the man is the probably the new philosophy t
# ----- diversity: 1.0
# ----- Generating with seed: "ed
# aspects. now in the case of philosoph"
# ed
# aspects. now in the case of philosophed work often is anothey in the surpadian feeling, ao, who
# chrided the advanted prelature and virtue), express himself "glanity to der besss are with the impulsess
# his constancy, understand him, is german there
# all suled on whow ciper, upon say--which would do not and throum ont isy his ejochegn, believe in-it still nace, we of there of times, immeasire a perverated,
# and first
# pointer raloned bish
# ----- diversity: 1.2
# ----- Generating with seed: "ed
# aspects. now in the case of philosoph"
# ed
# aspects. now in the case of philosophy, if as their
# rewadents fors afford. upon rready himsey artarfucre, for uith has been
# ute by looked in the spere suderist of the "to
# unpody
# museness: he charming owf
# most exnensmely, to which haver pertlind they, thoso, nor usoplt menn" oravial and existeant purquiegated apposed and yitulase---was life, mere with such consequently; and that
# their ejolerald of risund. even only eeture--wes tlanite
# Epoch 20/60
# 200285/200285 [==============================] - 439s 2ms/step - loss: 1.4409
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "ting? from
# german body, this self-lacera"
# ting? from
# german body, this self-laceration of the science of the subold the more in the experient the senses and sensible and the subon and the processes, and a soul and sensible the soul of the world and such a more soul and sensible the person the spiritual in the form of the such a subold to the be delicate that is the such a subin the experiences and the conscient and the problem of the such a person and the thing who is a says th
# ----- diversity: 0.5
# ----- Generating with seed: "ting? from
# german body, this self-lacera"
# ting? from
# german body, this self-laceration for the a possible to an advances of the sensible
# the disguise and destined to himself the hered for a france was be and conscience and because the disgus and an age which is necessary and terty it is the nor to the so the science and and conception of the will found, and into the more essenct of instance, to like who remoted
# in his instinct of cimmaning be enligise of the little could all th
# ----- diversity: 1.0
# ----- Generating with seed: "ting? from
# german body, this self-lacera"
# ting? from
# german body, this self-laceration withtr. even no at lac upon should have a regard and no seem in the deseries)--naturality. it discovedy to the who mich
# other and commot of in religiou such upon
# the conkelores of
# striving indisadisnces of the europeans in civilizable) of atooitful which wealist and error resolutions and courage mills there that a palsely usy--
#      other mabile
# to tofecow, continues and unguirition and compr
# ----- diversity: 1.2
# ----- Generating with seed: "ting? from
# german body, this self-lacera"
# ting? from
# german body, this self-laceral
# power us not the funken
# will presuil rewar; or fowled and
# manificd him esiablam be salnsist
# is still
# he woulzr, us
# no aps definece: but
# that shorl "syriafile by its most staris, let, with the differtiveness of anceltiftic it in planges.
# our under this amatity, that alare some, and as something tofacenless and a developmend,
# he shoith
# which yes, and re"must has fais to the hapicpes
# at lead for
# di
# Epoch 21/60
# 200285/200285 [==============================] - 441s 2ms/step - loss: 1.4114
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "ationship and
# equality, a calm confidenc"
# ationship and
# equality, a calm confidence of the senses of the present of the sense and conception of the state of the strength of all the sense, as a man are as a present, as a standart and the conceptio
